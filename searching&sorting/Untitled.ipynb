# %%
# cook your dish here

a = [3,6,6,4,5,8,1,9,10]
find = 1
i = 0 
n = len(a)

print('Searching....')

while i<n:
    if a[i] == find:
        print("Element found", a[i])

    i=i+1
# Out:
# Searching....
# Element found 1
